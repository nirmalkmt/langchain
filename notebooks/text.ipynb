# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model_name="claude-sonnet-5", temperature=0.9)
res = llm.invoke(input("Enter your prompt: "))
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File ~\OneDrive\Documents\aireadyengineer\env\Lib\site-packages\langchain_anthropic\chat_models.py:2259, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    2258 try:
# -> 2259     raw_response = self._create(payload)
#    2260 except anthropic.BadRequestError as e:
#
# File ~\OneDrive\Documents\aireadyengineer\env\Lib\site-packages\langchain_anthropic\chat_models.py:1846, in ChatAnthropic._create(self, payload)
#    1845         return self._client.beta.messages.with_raw_response.create(**payload)
# -> 1846     return self._client.messages.with_raw_response.create(**payload)
#    1847 except TypeError as e:
#
# File ~\OneDrive\Documents\aireadyengineer\env\Lib\site-packages\anthropic\_response.py:796, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
# ...
